# %% [markdown]
# ## ThinkDSP
#
# This notebook contains code examples from Chapter 4: Noise
#
# Copyright 2015 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](http://creativecommons.org/licenses/by/4.0/)

# %%
from __future__ import print_function, division

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import thinkdsp
import thinkplot
import thinkstats2 

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
thinkdsp.random_seed(17)

# %% [markdown]
# The simplest noise to generate is uncorrelated uniform (UU) noise:

# %%
signal = thinkdsp.UncorrelatedUniformNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Here's what a segment of it looks like:

# %%
segment = wave.segment(duration=0.1)
segment.plot(linewidth=1)
thinkplot.config(xlabel='time',
                 ylabel='amplitude',
                 ylim=[-1.05, 1.05],
                 legend=False)

# %% [markdown]
# And here's the spectrum:

# %%
spectrum = wave.make_spectrum()
spectrum.plot(linewidth=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='amplitude',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# In the context of noise it is more conventional to look at the spectrum of power, which is the square of amplitude:

# %%
spectrum.plot_power(linewidth=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# UU noise has the same power at all frequencies, on average, which we can confirm by looking at the normalized cumulative sum of power, which I call an integrated spectrum:

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()
thinkplot.config(xlabel='frequency (Hz)',
                ylabel='cumulative power',
                xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# A straight line in this figure indicates that UU noise has equal power at all frequencies, on average.  By analogy with light, noise with this property is called "white noise".
#
# ### Brownian noise
#
# Brownian noise is generated by adding up a sequence of random steps.

# %%
signal = thinkdsp.BrownianNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The sound is less bright, or more muffled, than white noise.
#
# Here's what the wave looks like:

# %%
wave.plot(linewidth=1)
thinkplot.config(xlabel='time',
                 ylabel='amplitude',
                 ylim=[-1.05, 1.05])

# %% [markdown]
# Here's what the power spectrum looks like on a linear scale.

# %%
spectrum = wave.make_spectrum()
spectrum.plot_power(linewidth=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# So much of the energy is at low frequencies, we can't even see the high frequencies.
#
# We can get a better view by plotting the power spectrum on a log-log scale.

# %%
# The f=0 component is very small, so on a log scale
# it's very negative.  If we clobber it before plotting,
# we can see the rest of the spectrum better.
spectrum.hs[0] = 0

spectrum.plot_power(linewidth=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power',
                 xscale='log',
                 yscale='log',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# Now the relationship between power and frequency is clearer.  The slope of this line is approximately -2, which indicates that $P = K / f^2$, for some constant $K$.

# %%
signal = thinkdsp.BrownianNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
spectrum = wave.make_spectrum()
result = spectrum.estimate_slope()
result.slope
# Out:
# -1.7846032211221736

# %% [markdown]
# The estimated slope of the line is closer to -1.8 than -2, for reasons we'll see later.
#
# ### Pink noise
#
# Pink noise is characterized by a parameter, $\beta$, usually between 0 and 2.  You can hear the differences below.
#
# With $\beta=0$, we get white noise:

# %%
signal = thinkdsp.PinkNoise(beta=0)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# With $\beta=1$, pink noise has the relationship $P = K / f$, which is why it is also called $1/f$ noise.

# %%
signal = thinkdsp.PinkNoise(beta=1)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# With $\beta=2$, we get Brownian (aka red) noise.

# %%
signal = thinkdsp.PinkNoise(beta=2)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The following figure shows the power spectrums for white, pink, and red noise on a log-log scale.

# %%
colors = ['orange', 'pink', 'red']
betas = [0, 1, 2]

for beta, color in zip(betas, colors):
    signal = thinkdsp.PinkNoise(beta=beta)
    wave = signal.make_wave(duration=0.5, framerate=1024)
    spectrum = wave.make_spectrum()
    spectrum.hs[0] = 0
    spectrum.plot_power(linewidth=1, color=color)
    
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power',
                 xscale='log',
                 yscale='log',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# ### Uncorrelated Gaussian noise
#
# An alternative to UU noise is uncorrelated Gaussian (UG noise).

# %%
signal = thinkdsp.UncorrelatedGaussianNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
wave.plot(linewidth=0.5)
thinkplot.config(xlabel='time',
                 ylabel='amplitude')

# %% [markdown]
# The spectrum of UG noise is also UG noise.

# %%
spectrum = wave.make_spectrum()
spectrum.plot_power(linewidth=1)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power',
                 xlim=[0, spectrum.fs[-1]])

# %% [markdown]
# We can use a normal probability plot to test the distribution of the power spectrum.

# %%
from thinkstats2 import NormalProbabilityPlot

NormalProbabilityPlot(spectrum.real, label='real part')
thinkplot.config(xlabel='normal sample',
                 ylabel='power',
                 ylim=[-250, 250],
                 legend=True,
                 loc='lower right')

# %% [markdown]
# A straight line on a normal probability plot indicates that the distribution of the real part of the spectrum is Gaussian.

# %%
NormalProbabilityPlot(spectrum.imag, label='imag part')
thinkplot.config(xlabel='normal sample',
                 ylabel='power',
                 ylim=[-250, 250],
                 legend=True,
                 loc='lower right')

# %% [markdown]
# And so is the imaginary part.

# %%
sounds = {
    'wind':{'file':'wind-realistic.wav'},
    'fire':{'file':'fireplace.wav'},
    'rain':{'file':'rain-atmo.wav'},
    'ocean':{'file':'ocean-noise-surf.wav'}
}

for k,v in sounds.items():
    wave = thinkdsp.read_wave(v['file'])
    
    segment1 = wave.segment(start=1, duration=1)
    spectrum1 = segment1.make_spectrum()
    
    segment2 = wave.segment(start=2, duration=1)
    spectrum2 = segment2.make_spectrum()

    v['wave'] = segment1
    v['spectrum1'] = spectrum1
    v['spectrum2'] = spectrum2
    v['segment1'] = segment1
    v['segment2'] = segment2

# %%
sounds['rain']['spectrum1'].plot_power()
sounds['rain']['spectrum2'].plot_power()
thinkplot.config(xlabel='Frequency (Hz)',
                 xscale='log', 
                 yscale='log')
sounds['rain']['wave'].make_audio()

sounds['rain']['spectrum1'].estimate_slope()
# Out:
# LinregressResult(slope=-2.4325354620619337, intercept=22.022776458885296, rvalue=-0.74440182604421368, pvalue=0.0, stderr=0.01408530857122409)

# %%
sounds['fire']['spectrum1'].plot_power()
sounds['fire']['spectrum2'].plot_power()
thinkplot.config(xlabel='Frequency (Hz)',
                 xscale='log', 
                 yscale='log')
sounds['fire']['wave'].make_audio()

sounds['fire']['spectrum1'].estimate_slope()
# Out:
# LinregressResult(slope=-1.0550174897400246, intercept=7.3310669556839692, rvalue=-0.50844672712859496, pvalue=0.0, stderr=0.012033165437524756)

# %%
sounds['wind']['spectrum1'].plot_power()
sounds['wind']['spectrum2'].plot_power()
thinkplot.config(xlabel='Frequency (Hz)',
                 xscale='log', 
                 yscale='log')
sounds['wind']['wave'].make_audio()

sounds['wind']['spectrum1'].estimate_slope()
# Out:
# LinregressResult(slope=-1.3627852079259222, intercept=14.976168870479292, rvalue=-0.71880497331830084, pvalue=0.0, stderr=0.008876645089599431)

# %%
sounds['ocean']['spectrum1'].plot_power()
sounds['ocean']['spectrum2'].plot_power()
thinkplot.config(xlabel='Frequency (Hz)',
                 xscale='log', 
                 yscale='log')
sounds['ocean']['wave'].make_audio()

sounds['ocean']['spectrum1'].estimate_slope()
# Out:
# LinregressResult(slope=-1.3258991592643439, intercept=17.36473898622522, rvalue=-0.70478859942669669, pvalue=0.0, stderr=0.008615211212511277)

# %%
thinkstats2.NormalProbabilityPlot(sounds['wind']['spectrum1'].real)

# %%
def bartlett_method(wave, seg_length=512, win_flag=True):
    spectrogram = wave.make_spectrogram(seg_length,win_flag)
    spectrums = spectrogram.spec_map.values()
    
    hs = np.sqrt(sum(spectrum.power for spectrum in spectrums) / len(spectrums))
    fs = spectrogram.any_spectrum().fs
    
    return thinkdsp.Spectrum(hs, fs, wave.framerate)

# %%
psd = bartlett_method(sounds['rain']['segment1'])
psd.plot_power()
psd = bartlett_method(sounds['rain']['segment2'])
psd.plot_power()
thinkplot.config(xlabel='Frequencies(HZ)',
                 ylabel='Power',
                 xscale='log',
                 yscale='log')

# %%
import pandas as pd

# %%
df = pd.read_csv('bitcoinDaily.csv')

# %%
prices = df['Close Price'].dropna()

# %%
bitWave = thinkdsp.Wave(prices)
bitWave.plot()

# %%
bitSpectrum = bitWave.make_spectrum()
bitSpectrum.plot_power()
thinkplot.config(xscale='log',
                 yscale='log')
bitSpectrum.estimate_slope()
# Out:
# LinregressResult(slope=-2.2874837271630031, intercept=29.535276397811398, rvalue=-0.8718623315595625, pvalue=3.669383180881322e-278, stderr=0.043071545601661966)

# %%
class UncorrelatedPoissonNoise(thinkdsp._Noise):
    
    def evaluate(self, ts):
        lam = self.amp
        ys = np.random.poisson(lam=lam, size=len(ts))
        return ys

# %%
framerate = 10000
amp = 0.001
duration = 1

poi_noise = UncorrelatedPoissonNoise(amp=amp)
poi_wave = poi_noise.make_wave(duration=duration, framerate=framerate)
poi_wave.plot()
poi_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
poi_spectrum = poi_wave.make_spectrum()
poi_spectrum.plot_power()
thinkplot.config(xlabel='Frequencies(HZ)',
                 ylabel='Power',
                 xscale='log',
                 yscale='log')

# %%
framerate = 10000
amp = 1
duration = 1

poi_noise = UncorrelatedPoissonNoise(amp=amp)
poi_wave = poi_noise.make_wave(duration=duration, framerate=framerate)
poi_wave.plot()
poi_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
poi_spectrum = poi_wave.make_spectrum()
poi_spectrum.plot_power()
thinkplot.config(xlabel='Frequencies(HZ)',
                 ylabel='Power',
                 xscale='log',
                 yscale='log')

# %%
poi_spectrum.estimate_slope()
# Out:
# LinregressResult(slope=0.014799494814879655, intercept=8.5224184994239849, rvalue=0.011639515110144678, pvalue=0.41058755786512369, stderr=0.017983923885661272)

# %%
poi_spectrum.hs[0] = 0

thinkplot.preplot(2, cols=2)
thinkstats2.NormalProbabilityPlot(poi_spectrum.real, label='real')
thinkplot.config(xlabel='Normal sample',
                 ylabel='Power',
                 legend=True,
                 loc='lower right')

thinkplot.subplot(2)
thinkstats2.NormalProbabilityPlot(poi_spectrum.imag, label='imag')
thinkplot.config(xlabel='Normal sample',
                     loc='lower right')

# %%
def voss(nrows, ncols=16):
    arr = np.empty((nrows,ncols))
    arr.fill(np.nan)
    arr[0,:] = np.random.random(ncols)
    arr[:,0] = np.random.random(nrows)
    
    cols = np.random.geometric(p=0.5, size=nrows)
    cols[cols >= ncols] = 0
    rows = np.random.randint(nrows, size=nrows)
    arr[rows, cols] = np.random.random(nrows)
    
    df = pd.DataFrame(arr)
    df.fillna(method='ffill',axis=0,inplace=True)
    
    total = df.sum(axis=1)
    return total.values

# %%
ys = voss(11025)
ys
# Out:
# array([ 8.54851077,  8.32314568,  8.44310885, ...,  8.32665832,
#         9.39275643,  9.78945414])

# %%
pink_wave = thinkdsp.Wave(ys)
pink_wave.plot()

# %%
pink_spectrum = pink_wave.make_spectrum()
pink_spectrum.plot_power()
thinkplot.config(xscale='log',
                 yscale='log',
                 xlabel='Frequency',
                 ylabel='Power')

# %%
pink_spectrum.estimate_slope()
# Out:
# LinregressResult(slope=-0.99455356302179398, intercept=14.912610080834082, rvalue=-0.61021302813476064, pvalue=0.0, stderr=0.017395071982934444)

# %%
seg_length = 64 * 1024
iters = 100
wave = thinkdsp.Wave(voss(seg_length * iters))
len(wave)
# Out:
# 6553600

# %%
spectrum = bartlett_method(wave, seg_length=seg_length)
spectrum.hs[0]=0
spectrum.plot_power()
thinkplot.config(xscale='log',
                 yscale='log',
                 xlabel='Frequency',
                 ylabel='Power')

# %%
spectrum.estimate_slope()
# Out:
# LinregressResult(slope=-1.0031257144349008, intercept=16.42642630390209, rvalue=-0.98687810029479073, pvalue=0.0, stderr=0.00090670102500681454)
